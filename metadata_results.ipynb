# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('completeness.csv')
df.head()
# Out:
#         Cohort  Total Metadata
# 0  E-MEXP-3567           66.66
# 1  E-MEXP-3850           72.22
# 2  E-MTAB-1548           77.77
# 3     GSE10474           66.66
# 4     GSE13015           72.22

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
Cohorts = ['E-MEXP-3567','E-MEXP-3850','E-MTAB-1548','GSE10474','GSE13015','GSE27131','GSE32707','GSE40586','GSE63042','GSE66099','GSE66890','GSE21802','GSE33341','GSE54514','GSE63990','E-MTAB-4421','GSE110487','GSE65682','GSE4607','GSE8121','GSE9960','GSE13904','GSE25504','GSE26378','GSE28750','GSE64457','GSE74224','GSE95233','GSE63311']
Total_Metadata = [66.66, 72.22, 77.77, 66.66, 72.22, 55.55, 66.66, 55.55, 61.11, 38.88, 72.22, 66.66, 72.22, 83.33, 55.55, 72.22, 55.55, 77.77, 77.77, 66.66, 61.11, 66.66, 72.22, 66.66, 55.55, 55.55, 61.11, 66.66, 38.88] 
ax.bar(Cohorts,Total_Metadata, color='DarkCyan')
ax.set_xlabel('Cohorts')
ax.set_ylabel('Total Metadata')
axes = plt.gca()
axes.set_ylim([0,100])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# The percentage of reported clinical phenotypes varied from **83.3%** for the most complete study to **38.9%** for the least.

# %%
df2=pd.read_csv('clinical_phenotypes.csv')
df2.head()

# %%
ax = sns.barplot(data=df2, x='Clinical Phenotype', y='Total Metadata', palette='mako')
ax.set_xticklabels(ax.get_xticklabels(), rotation=60, ha="right")
# Out:
# [Text(0, 0, 'Disease condition'),
#  Text(0, 0, 'Age'),
#  Text(0, 0, 'Organism'),
#  Text(0, 0, 'Sex'),
#  Text(0, 0, 'Tissue type'),
#  Text(0, 0, 'Country'),
#  Text(0, 0, 'Ancestry'),
#  Text(0, 0, 'Mortality'),
#  Text(0, 0, 'Clinical Severity')]

# %% [markdown]
# The most reported clinical phenotypes were **organism and tissue type (100%)** while the least reported was **ancestry (22.4%)**

# %%
df3=pd.read_csv('individual_phenotypes.csv')
df3.head()
# Out:
#   Clinical Phenotype  Reported Metadata                  Type
# 0  Disease condition             100.00  Original Publication
# 1  Disease condition              82.75   Public Repositories
# 2                Age              89.65  Original Publication
# 3                Age              41.38   Public Repositories
# 4           Organism             100.00  Original Publication

# %%
ax = sns.barplot(data=df3, x='Clinical Phenotype', y='Reported Metadata',hue='Type', palette='mako')
ax.set_xticklabels(ax.get_xticklabels(), rotation=60, ha="right")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# Apart from tissue type and organism, the **least discrepancy** was observed for reporting the **disease condition**, with **100%** being reported on publications and **82.8%** reported on the repositories. On the other hand, the **largest difference** between publications and repositories was observed for the country of residence of the patient. While the country is mentioned on **89.7%** of the publications, it was reported by a mere **3.4%** on public repositories.

# %%
df4=pd.read_csv('comparison.csv')
df4.head()
# Out:
#         Cohort  Reported Metadata                  Type
# 0  E-MEXP-3567              77.77  Original Publication
# 1  E-MEXP-3567              55.55     Public Repository
# 2  E-MEXP-3850              88.88  Original Publication
# 3  E-MEXP-3850              66.66     Public Repository
# 4  E-MTAB-1548              88.88  Original Publication

# %%
ax = sns.barplot(data=df4, x='Cohort', y='Reported Metadata', hue='Type', palette='mako')
ax.set_xlabel("Cohort",fontsize=30)
ax.set_ylabel("Reported Metadata",fontsize=30)
ax.set_xticklabels(ax.get_xticklabels(), rotation=60, ha="right")
plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
fig = plt.gcf()
fig.set_size_inches(30, 10)
ax.tick_params(axis='x', labelsize=24)
ax.tick_params(axis='y', labelsize=24)
plt.setp(ax.get_legend().get_texts(), fontsize='24') # for legend text
# Out:
# [None, None, None, None]

# %% [markdown]
# The most reported clinical phenotypes on publications were the **disease condition, organism, and tissue type**, each being **consistently reported** across all studies, while this was also the case for the latter two on public repositories. The **least reported** clinical variable on publications was **ancestry (37.9%)**, while on the repositories it was the **country of residence (3.4%)**.
